# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
#Extracrting the data
df=pd.read_csv("C:\\Users\\User\\Downloads\\travel_dataset.csv")
df.
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %% [markdown]
# ### Basic  Attributes

# %%
#to know the datatypes and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
#setting column names
df.columns=df.columns.str.strip().str.replace(" ","_").str.lower()

# %%
df.tail(10)
# Out:
#       customerid  prodtaken   age    typeofcontact  citytier  durationofpitch  \
# 4878      204878          1  35.0     Self Enquiry         1             17.0
# 4879      204879          1  26.0     Self Enquiry         2             27.0
# 4880      204880          1  59.0     Self Enquiry         1             28.0
# 4881      204881          1  41.0     Self Enquiry         2             25.0
# 4882      204882          1  37.0     Self Enquiry         2             20.0
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
#           occupation  gender  numberofpersonvisiting  numberoffollowups  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerid                4888 non-null   int64
#  1   prodtaken                 4888 non-null   int64
#  2   age                       4662 non-null   float64
#  3   typeofcontact             4863 non-null   object
#  4   citytier                  4888 non-null   int64
#  5   durationofpitch           4637 non-null   float64
#  6   occupation                4888 non-null   object
#  7   gender                    4888 non-null   object
#  8   numberofpersonvisiting    4888 non-null   int64
#  9   numberoffollowups         4843 non-null   float64
#  10  productpitched            4888 non-null   object
#  11  preferredpropertystar     4862 non-null   float64
#  12  maritalstatus             4888 non-null   object
# ...

# %%
df["prodtaken"]=df["prodtaken"].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerid                4888 non-null   int64
#  1   prodtaken                 4888 non-null   object
#  2   age                       4662 non-null   float64
#  3   typeofcontact             4863 non-null   object
#  4   citytier                  4888 non-null   int64
#  5   durationofpitch           4637 non-null   float64
#  6   occupation                4888 non-null   object
#  7   gender                    4888 non-null   object
#  8   numberofpersonvisiting    4888 non-null   int64
#  9   numberoffollowups         4843 non-null   float64
#  10  productpitched            4888 non-null   object
#  11  preferredpropertystar     4862 non-null   float64
#  12  maritalstatus             4888 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerid                    0
# prodtaken                     0
# age                         226
# typeofcontact                25
# citytier                      0
# durationofpitch             251
# occupation                    0
# gender                        0
# numberofpersonvisiting        0
# numberoffollowups            45
# productpitched                0
# preferredpropertystar        26
# maritalstatus                 0
# numberoftrips               140
# passport                      0
# pitchsatisfactionscore        0
# owncar                        0
# numberofchildrenvisiting     66
# designation                   0
# monthlyincome               233
# dtype: int64

# %%
#treating missing values
df["numberoffollowups"]=df["numberoffollowups"].fillna(df["numberoffollowups"].mode()[0])
df["preferredpropertystar"]=df["preferredpropertystar"].fillna(df["preferredpropertystar"].mode()[0])
df["durationofpitch"]=df["durationofpitch"].fillna(df["durationofpitch"].mode()[0])
df["typeofcontact"]=df["typeofcontact"].fillna(df["typeofcontact"].mode()[0])
df["numberoftrips"]=df["numberoftrips"].fillna(df["numberoftrips"].mode()[0])
df["numberofchildrenvisiting"]=df["numberofchildrenvisiting"].fillna(df["numberofchildrenvisiting"].mode()[0])
df["age"]=df["age"].fillna(df["age"].mode()[0])
df["monthlyincome"]=df["monthlyincome"].fillna(df["monthlyincome"].median())
df.isnull().sum()
# Out:
# customerid                  0
# prodtaken                   0
# age                         0
# typeofcontact               0
# citytier                    0
# durationofpitch             0
# occupation                  0
# gender                      0
# numberofpersonvisiting      0
# numberoffollowups           0
# productpitched              0
# preferredpropertystar       0
# maritalstatus               0
# numberoftrips               0
# passport                    0
# pitchsatisfactionscore      0
# owncar                      0
# numberofchildrenvisiting    0
# designation                 0
# monthlyincome               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerid                4888 non-null   int64
#  1   prodtaken                 4888 non-null   object
#  2   age                       4888 non-null   float64
#  3   typeofcontact             4888 non-null   object
#  4   citytier                  4888 non-null   int64
#  5   durationofpitch           4888 non-null   float64
#  6   occupation                4888 non-null   object
#  7   gender                    4888 non-null   object
#  8   numberofpersonvisiting    4888 non-null   int64
#  9   numberoffollowups         4888 non-null   float64
#  10  productpitched            4888 non-null   object
#  11  preferredpropertystar     4888 non-null   float64
#  12  maritalstatus             4888 non-null   object
# ...

# %%
df = df.astype({'preferredpropertystar': int, 'monthlyincome': int,'numberofchildrenvisiting':int,"numberoftrips":int,"numberoffollowups":int,"durationofpitch":int,"age":int})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerid                4888 non-null   int64
#  1   prodtaken                 4888 non-null   object
#  2   age                       4888 non-null   int32
#  3   typeofcontact             4888 non-null   object
#  4   citytier                  4888 non-null   int64
#  5   durationofpitch           4888 non-null   int32
#  6   occupation                4888 non-null   object
#  7   gender                    4888 non-null   object
#  8   numberofpersonvisiting    4888 non-null   int64
#  9   numberoffollowups         4888 non-null   int32
#  10  productpitched            4888 non-null   object
#  11  preferredpropertystar     4888 non-null   int32
#  12  maritalstatus             4888 non-null   object
#  13  numberoftrips             4888 non-null   int32
# ...

# %% [markdown]
# ## Non visual Analysis

# %%
discrete_df = df.select_dtypes(include=['object'])
def discrete_univariate_analysis(discrete_data):
  for col_name in discrete_data:
    print("*"*10, col_name, "*"*10)
    print(discrete_data[col_name].agg(['count', 'nunique', 'unique']))
    print('Value Counts: \n', discrete_data[col_name].value_counts())
    print()

# %%
discrete_univariate_analysis(discrete_df)
# Out:
# ********** prodtaken **********
# count        4888
# nunique         2
# unique     [1, 0]
# Name: prodtaken, dtype: object
# Value Counts:
#  0    3968
# 1     920
# Name: prodtaken, dtype: int64
#
# ********** typeofcontact **********
# count                                 4888
# nunique                                  2
# unique     [Self Enquiry, Company Invited]
# Name: typeofcontact, dtype: object
# Value Counts:
#  Self Enquiry       3469
# Company Invited    1419
# Name: typeofcontact, dtype: int64
#
# ********** occupation **********
# count                                                   4888
# nunique                                                    4
# unique     [Salaried, Free Lancer, Small Business, Large ...
# Name: occupation, dtype: object
# Value Counts:
#  Salaried          2368
# Small Business    2084
# Large Business     434
# Free Lancer          2
# Name: occupation, dtype: int64
#
# ********** gender **********
# count                         4888
# ...

# %%
df=df.replace('Fe Male','Female')
df['gender'].value_counts()
# Out:
# Male      2916
# Female    1972
# Name: gender, dtype: int64

# %%
numerical_df = df.select_dtypes(include=['int32', 'float64','int64'])
def numerical_univariate_analysis(numerical_data):
  for col_name in numerical_data:
    print("*"*10, col_name, "*"*10)
    print(numerical_data[col_name].agg(['min', 'max', 'mean', 'median', 'std','skew','kurt']))
    print()

# %%
numerical_univariate_analysis(numerical_df)
# Out:
# ********** customerid **********
# min       200000.000000
# max       204887.000000
# mean      202443.500000
# median    202443.500000
# std         1411.188388
# skew           0.000000
# kurt          -1.200000
# Name: customerid, dtype: float64
#
# ********** age **********
# min       18.000000
# max       61.000000
# mean      37.501023
# median    36.000000
# std        9.115070
# skew       0.428832
# kurt      -0.325128
# Name: age, dtype: float64
#
# ********** citytier **********
# min       1.000000
# max       3.000000
# mean      1.654255
# median    1.000000
# std       0.916583
# skew      0.736531
# kurt     -1.403305
# Name: citytier, dtype: float64
#
# ********** durationofpitch **********
# min         5.000000
# max       127.000000
# mean       15.157529
# median     13.000000
# std         8.420753
# skew        1.816581
# kurt       12.004285
# Name: durationofpitch, dtype: float64
#
# ********** numberofpersonvisiting **********
# min       1.000000
# ...

# %%
import seaborn as sns

# %%
sns.countplot(x='prodtaken', data=df)
# Out:
# <Axes: xlabel='prodtaken', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerid                4888 non-null   int64
#  1   prodtaken                 4888 non-null   object
#  2   age                       4888 non-null   int32
#  3   typeofcontact             4888 non-null   object
#  4   citytier                  4888 non-null   int64
#  5   durationofpitch           4888 non-null   int32
#  6   occupation                4888 non-null   object
#  7   gender                    4888 non-null   object
#  8   numberofpersonvisiting    4888 non-null   int64
#  9   numberoffollowups         4888 non-null   int32
#  10  productpitched            4888 non-null   object
#  11  preferredpropertystar     4888 non-null   int32
#  12  maritalstatus             4888 non-null   object
#  13  numberoftrips             4888 non-null   int32
# ...

# %%
df.shape
# Out:
# (4888, 20)

# %% [markdown]
# ### Visual Analysis

# %%
# !pip install scipy

# %%
from scipy import stats

# %%
#checking if the income is normal dist or not
import matplotlib.pyplot as plt
stats.probplot(df["monthlyincome"],dist="norm",plot=plt)
plt.grid()

# %%
sns.boxenplot(x='monthlyincome', data=df)
# Out:
# <Axes: xlabel='monthlyincome'>

# %%
df["monthlyincome"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df[df["monthlyincome"]>40000].head()sp
# Out:
#       customerid prodtaken  age typeofcontact  citytier  durationofpitch  \
# 38        200038         0   36  Self Enquiry         1               11
# 2482      202482         0   37  Self Enquiry         1               12
#
#      occupation  gender  numberofpersonvisiting  numberoffollowups  \
# 38     Salaried  Female                       2                  4
# 2482   Salaried  Female                       3                  5
#
#      productpitched  preferredpropertystar maritalstatus  numberoftrips  \
# 38            Basic                      3      Divorced              1
# 2482          Basic                      5      Divorced              2
#
#       passport  pitchsatisfactionscore  owncar  numberofchildrenvisiting  \
# 38           1                       2       1                         0
# 2482         1                       2       1                         1
#
#      designation  monthlyincome
# 38     Executive          95000
# ...

# %%
#outlier treatment
df_clean=df[df.monthlyincome<=30000]
df_clean["monthlyincome"].plot(kind="box")
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
stats.probplot(df_clean["monthlyincome"],dist="norm",plot=plt)
plt.grid()

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4298 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerid                4298 non-null   int64
#  1   prodtaken                 4298 non-null   object
#  2   age                       4298 non-null   int32
#  3   typeofcontact             4298 non-null   object
#  4   citytier                  4298 non-null   int64
#  5   durationofpitch           4298 non-null   int32
#  6   occupation                4298 non-null   object
#  7   gender                    4298 non-null   object
#  8   numberofpersonvisiting    4298 non-null   int64
#  9   numberoffollowups         4298 non-null   int32
#  10  productpitched            4298 non-null   object
#  11  preferredpropertystar     4298 non-null   int32
#  12  maritalstatus             4298 non-null   object
#  13  numberoftrips             4298 non-null   int32
# ...

# %%
sns.countplot(x='prodtaken', data=df_clean)
# Out:
# <Axes: xlabel='prodtaken', ylabel='count'>

# %%
sns.countplot(data=df_clean,x='typeofcontact')
# Out:
# <Axes: xlabel='typeofcontact', ylabel='count'>

# %%
sns.countplot(data=df_clean,x='occupation')
# Out:
# <Axes: xlabel='occupation', ylabel='count'>

# %%
sns.boxenplot(data=df_clean,x='durationofpitch')
# Out:
# <Axes: xlabel='durationofpitch'>

# %%
sns.countplot(data=df_clean,x="designation")
# Out:
# <Axes: xlabel='designation', ylabel='count'>

# %%
sns.countplot(data=df_clean,x="preferredpropertystar")
# Out:
# <Axes: xlabel='preferredpropertystar', ylabel='count'>

# %%
sns.countplot(data=df_clean,x="passport")
# Out:
# <Axes: xlabel='passport', ylabel='count'>

# %% [markdown]
# ### Bivariate Analysis

# %%
#prodtaken v/s gender

# %%
crosstab = pd.crosstab(df_clean['gender'], df_clean['prodtaken'])

print(crosstab)
# Out:
# prodtaken     0    1
# gender
# Female     1397  316
# Male       2041  544

# %%
sns.countplot(data=df_clean, x='gender', hue='prodtaken')

plt.title('prodtaken vs gender')
# Out:
# Text(0.5, 1.0, 'prodtaken vs gender')

# %%
#prodtaken v/s type of contact
c=pd.crosstab(df_clean["typeofcontact"],df_clean["prodtaken"])
c
# Out:
# prodtaken           0    1
# typeofcontact
# Company Invited   981  294
# Self Enquiry     2457  566

# %%
sns.countplot(data=df_clean, x='typeofcontact', hue='prodtaken')

plt.title('prodtaken vs typeofcontact')
# Out:
# Text(0.5, 1.0, 'prodtaken vs typeofcontact')

# %%
crosstab=pd.crosstab(df_clean["occupation"],df["prodtaken"])
crosstab
# Out:
# prodtaken          0    1
# occupation
# Free Lancer        0    2
# Large Business   285  114
# Salaried        1678  383
# Small Business  1475  361

# %%
sns.countplot(data=df_clean, x='occupation', hue='prodtaken')

plt.title('prodtaken vs occupation')
# Out:
# Text(0.5, 1.0, 'prodtaken vs occupation')

# %%
crosstab=pd.crosstab(df_clean["productpitched"],df_clean["prodtaken"])
crosstab
# Out:
# prodtaken          0    1
# productpitched
# Basic           1288  538
# Deluxe          1528  195
# King               0    2
# Standard         557  115
# Super Deluxe      65   10

# %%
sns.countplot(data=df_clean, x='productpitched', hue='prodtaken')

plt.title('prodtaken vs productpitched')
# Out:
# Text(0.5, 1.0, 'prodtaken vs productpitched')

# %%
crosstab=pd.crosstab(df_clean["designation"],df_clean["prodtaken"])
crosstab
# Out:
# prodtaken          0    1
# designation
# AVP               65   10
# Executive       1288  538
# Manager         1528  195
# Senior Manager   557  115
# VP                 0    2

# %%
sns.countplot(data=df_clean, x='designation', hue='prodtaken')

plt.title('prodtaken vs designation')
# Out:
# Text(0.5, 1.0, 'prodtaken vs designation')

# %%
group = df_clean.groupby('prodtaken')

group['passport'].agg(['min', 'max', 'mean', 'median'])
# Out:
#            min  max      mean  median
# prodtaken
# 0            0    1  0.228912     0.0
# 1            0    1  0.537209     1.0

# %%
sns.boxplot(data=df, x='passport', y='prodtaken')
# Out:
# <Axes: xlabel='passport', ylabel='prodtaken'>

# %%
group = df_clean.groupby('prodtaken')

group['preferredpropertystar'].agg(['min', 'max', 'mean', 'median'])
# Out:
#            min  max      mean  median
# prodtaken
# 0            3    5  3.538394     3.0
# 1            3    5  3.744186     3.0

# %%
sns.histplot(data=df_clean,x='preferredpropertystar', y='prodtaken')
# Out:
# <Axes: xlabel='preferredpropertystar', ylabel='prodtaken'>

# %%
group = df_clean.groupby('prodtaken')

group['monthlyincome'].agg(['min', 'max', 'mean', 'median'])
# Out:
#              min    max          mean   median
# prodtaken
# 0           1000  29923  22251.953461  22157.5
# 1          16009  29532  21312.289535  21105.0

# %%
sns.boxenplot(data=df_clean,x='prodtaken', y='monthlyincome')
# Out:
# <Axes: xlabel='prodtaken', ylabel='monthlyincome'>

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4298 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customerid                4298 non-null   int64
#  1   prodtaken                 4298 non-null   object
#  2   age                       4298 non-null   int32
#  3   typeofcontact             4298 non-null   object
#  4   citytier                  4298 non-null   int64
#  5   durationofpitch           4298 non-null   int32
#  6   occupation                4298 non-null   object
#  7   gender                    4298 non-null   object
#  8   numberofpersonvisiting    4298 non-null   int64
#  9   numberoffollowups         4298 non-null   int32
#  10  productpitched            4298 non-null   object
#  11  preferredpropertystar     4298 non-null   int32
#  12  maritalstatus             4298 non-null   object
#  13  numberoftrips             4298 non-null   int32
# ...

# %% [markdown]
# ## Statistiacl Tests

# %%
def chi_square(freq_table, significance_level):
    stat, p_val, dof, expected = stats.chi2_contingency(freq_table)
    
    print('stat=%.3f, p=%.3f' % (stat, p_val))
    
    if p_val < significance_level:
        print('Reject null hypothesis (H0): Probably dependent')
    else:
        print('Fail to Reject null hypothesis (H0): Probably independent')

# %%
freq_table = pd.crosstab(df_clean['prodtaken'], df_clean['gender'])

freq_table
# Out:
# gender     Female  Male
# prodtaken
# 0            1397  2041
# 1             316   544

# %%
chi_square(freq_table, significance_level=0.05)
# Out:
# stat=4.182, p=0.041
# Reject null hypothesis (H0): Probably dependent

# %%
freq_table = pd.crosstab(df_clean['prodtaken'], df_clean['occupation'])

freq_table
# Out:
# occupation  Free Lancer  Large Business  Salaried  Small Business
# prodtaken
# 0                     0             285      1678            1475
# 1                     2             114       383             361

# %%
chi_square(freq_table, significance_level=0.05)
# Out:
# stat=29.028, p=0.000
# Reject null hypothesis (H0): Probably dependent

# %%
freq_table = pd.crosstab(df_clean['prodtaken'], df_clean['productpitched'])

freq_table
# Out:
# productpitched  Basic  Deluxe  King  Standard  Super Deluxe
# prodtaken
# 0                1288    1528     0       557            65
# 1                 538     195     2       115            10

# %%
chi_square(freq_table, significance_level=0.05)
# Out:
# stat=196.900, p=0.000
# Reject null hypothesis (H0): Probably dependent

# %%
freq_table = pd.crosstab(df_clean['prodtaken'], df_clean['designation'])

freq_table
# Out:
# designation  AVP  Executive  Manager  Senior Manager  VP
# prodtaken
# 0             65       1288     1528             557   0
# 1             10        538      195             115   2

# %%
chi_square(freq_table, significance_level=0.05)
# Out:
# stat=196.900, p=0.000
# Reject null hypothesis (H0): Probably dependent

# %% [markdown]
# ## num v/s cat

# %%
def two_sample_ttest(data1, data2, significance_level):
    stat, p_val = stats.ttest_ind(data1, data2)
    
    print('stat=%.3f, p_val=%.3f' % (stat, p_val))
    
    if p_val < significance_level:
        print('Reject null hypothesis (H0): There is a significant difference between the groups.')
    else:
        print('Fail to Reject null hypothesis (H0): There is no significant difference between the groups.')

# %%
df['prodtaken'].value_counts()
# Out:
# 0    3968
# 1     920
# Name: prodtaken, dtype: int64
